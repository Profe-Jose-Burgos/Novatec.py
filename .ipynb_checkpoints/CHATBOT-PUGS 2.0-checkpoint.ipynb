# %% [markdown]
# # NOVATEC.PY - HACKATHON SIC 2022-23

# %% [markdown]
# ## Chatbot - PUGS 2.0

# %%
import pickle
import nltk
import json
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
from nltk.stem import SnowballStemmer
import random

# %%
def guardar_json(datos):
    archivo = open("intenciones.json", "w")
    json.dump(datos, archivo, indent = 4)

# %%
biblioteca = {"intenciones":
              [
                  {"etiqueta":"saludos",
                   "patrones":["hola",
                               "hey",
                               "buenas",
                               "buenos dias",
                               "buenas noches",
                               "buenas tardes",
                               "hay alguien ahi?",
                               "que tal?"
                               "saludos",
                               "como estas?"
                              ],
                   "respuestas":["GUAU GUAU!, me llamo PUGS! su sistema de ayuda para atencion en sus preguntas o dudas sobre el centro de atencion para su(s) mascota(s). En que te puedo ayudar?"],
                   "contexto":[""]
                },
                  
                {"etiqueta":"despedidas",
                 "patrones":["adios",
                             "hasta luego",
                             "hasta pronto",
                             "hasta la proxima",
                             "chao",
                             "bye",
                             "nos vemos"
                             ],
                 "respuestas":["Gracias por consultarme humano!! Hasta Pronto :)",
                               "Hasta la proxima! Nos vemos!",
                               "Adios, espero haberte ayudado humano :)"],
                 "contexto":[""]
                },
                  
                  {"etiqueta":"agradecimientos",
                   "patrones":["gracias",
                               "gracias por tu ayuda",
                               "muchas gracias",
                               "gracias por tu tiempo",
                               "te lo agradezco",
                               "has sido de gran ayuda",
                               "mil gracias",
                               "genial",
                               "excelente",
                               "brutal",
                               "muy amable"
                              ],
                   "respuestas":["Espero haberte ayudado, eres un humano genial!!",
                                "De nada, estoy para ayudarte!",
                                "Ha sido todo un placer humano!",
                                "Gracias a usted por elegirnos!"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"servicios",
                   "patrones":["servicios",
                               "que servicios ofrecen?",
                               "de que servicios disponen?",
                               "realizan laboratorios?",
                               "realizan endoscopia?",
                               "medicina preventiva",
                               "medicina general",
                               "medicina especializada",
                               "ofrecen cirugias especializadas?",
                               "ofrecen cirugia general?",
                               "tienen servicios de acupuntura?",
                               "servicos de cardiograma",
                               "hacen ultrasonidos?",
                               "realizan electrocardiogramas?",
                               "hacen rayos x?",
                               "ofrecen servicios de urgencia?",
                               "que hacen?"
                              ],
                   "respuestas":["Ofrecemos los siguientes servicios:\n-Medicina Preventiva\n-Medicina General\n -Medicina Especializada\n -Cirugia General\n -Cirugias Especializadas\n -Acupuntura\n -Cardiogramas\n -Ultrasonidos\n -Electrocardiograma\n -Rayos X\n -Endoscopia\n -Laboratorios\n -Urgencia"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"horarios",
                   "patrones":["horario",
                               "que horario tienen?",
                               "a que hora atienden?",
                               "cual es su horario de atencion?",
                               "estan disponibles?",
                               "estan abiertos?",
                               "estan cerrados?",
                               "que dia atienden?",
                               "atienden?"
                              ],
                   "respuestas":["Estamos abiertos de Lunes a Sabados de 6:00 a.m - 10:00 p.m y los Domingos de 6:00 a.m - 7:00 p.m"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"ubicacion",
                   "patrones":["ubicacion",
                               "donde se encuentran ubicados?",
                               "en donde estan localizados?",
                               "Donde estan?",
                               "Donde los puedo encontrar?",
                               "Como puedo llegar?",
                               "podrian enviar la ubicacion?",
                               "localizacion",
                               "en que parte se encuentran ubicados?"
                              ],
                   "respuestas":["Nos encontramos ubicados en Chanis, Campo Limbergh, Casa H-49, Ciudad de Panama, Panama\n En el siguiente link se muestra la ubicacion exacta: https://goo.gl/maps/tacZVtLWV5ENFv6W7"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"contacto",
                   "patrones":["contacto",
                               "como los puedo contactar?",
                               "tiene algun numero de contacto?",
                               "tienen whatsapp?",
                               "tienen instagram?",
                               "tienen algun numero de telefono?"
                              ],
                   "respuestas":["Puedes contactarte directamente con nosotros al Whatsapp: +507 62840188 o a nuestro numero telefónico: 391-8357 / 391-8358\n Tambien nos puedes seguir en nuestro Instagram para no perderte de ninguna promocion!!: https://www.instagram.com/clinicavetpatasyhuellas/?hl=es"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"sinrespuesta",
                   "patrones":[""],
                   "respuestas":["no se ha detectado respuesta. Puedes hacerme preguntas como:\nHorario \nServicios \nUbicacion \nContacto",
                                 "ouh, no comprendo lo que me quieres decir humano :(. Puedes hacerme preguntas como:\nHorario \nServicios \nUbicacion \nContacto",
                                 "lo siento, podrias decirlo de otro manera?, a veces me cuesta entender a los humanos. Puedes hacerme preguntas como:\nHorario \nServicios \nUbicacion \nContacto"],
                   "contexto":[""]
                  }
              ]
    
            }

guardar_json(biblioteca)

# %%
palabras_ignoradas = ["?", "¿", "!", "¡", ",", ".", "|", "°", "*"]
archivo_json = open("intenciones.json").read()
intenciones = json.loads(archivo_json)

# %%
palabras = []
categorias = []
documentos = []

for intencion in intenciones["intenciones"]:
    for patron in intencion["patrones"]:
        w_token = nltk.word_tokenize(patron)
        palabras.extend(w_token)
        
        
        documentos.append((w_token, intencion["etiqueta"]))
        
        if intencion["etiqueta"] not in categorias:
            categorias.append(intencion["etiqueta"])

# %%
lematizar = SnowballStemmer('spanish')
palabras = [lematizar.stem(pal.lower()) for pal in palabras if pal not in palabras_ignoradas]

pickle.dump(palabras, open("palabras.pkl", "wb"))
pickle.dump(categorias, open("categorias.pkl", "wb"))

# %%
pickle.dump(palabras, open("palabras.pkl", "wb"))
pickle.dump(categorias, open("categorias.pkl", "wb"))

# %%
entrenamiento=[]
output_empty=[0]*len(categorias)

for doc in documentos:
    contenedor=[]
    patrones_pal=doc[0]
    patrones_pal=[lematizar.stem(palabra.lower()) for palabra in patrones_pal if palabra not in palabras_ignoradas ]
    
    for palabra in palabras:
        contenedor.append(1) if palabra in patrones_pal else contenedor.append(0)
        
    output_row=list(output_empty)
    output_row[categorias.index(doc[1])] = 1
    
    entrenamiento.append([contenedor, output_row])
    
entrenamiento=np.array(entrenamiento)
x_train = list(entrenamiento[:,0])
y_train = list(entrenamiento[:,1])
# Out:
# C:\Users\psthe\AppData\Local\Temp\ipykernel_7364\1803794437.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   entrenamiento=np.array(entrenamiento)

# %%
modelo = Sequential()

modelo.add(Dense(128, input_shape=(len(x_train[0]),), activation='relu')) 
modelo.add(Dropout(0.5))
modelo.add(Dense(64,activation='relu')) 
modelo.add(Dropout(0.5))
modelo.add(Dense(len(y_train[0]),activation='softmax'))

sgd=SGD(learning_rate=0.01,decay=1e-6,momentum=0.9,nesterov=True) 

modelo.compile(loss="categorical_crossentropy",optimizer=sgd,metrics=["accuracy"])

hist=modelo.fit(np.array(x_train),np.array(y_train),epochs=300,batch_size=5,verbose=1)
modelo.save("modelo_chatbot_pugs.h5",hist)
print("modelo creado")

#print("###############MODELO CREADO####################")
#reemplazar los nombres de la extensiones si es necesario
# Out:
# Epoch 1/300
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0784 - accuracy: 0.1304
# Epoch 2/300
# 14/14 [==============================] - 0s 2ms/step - loss: 1.9270 - accuracy: 0.2754
# Epoch 3/300
# 14/14 [==============================] - 0s 2ms/step - loss: 1.7491 - accuracy: 0.3333
# Epoch 4/300
# 14/14 [==============================] - 0s 2ms/step - loss: 1.6129 - accuracy: 0.4058
# Epoch 5/300
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4313 - accuracy: 0.5072
# Epoch 6/300
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3231 - accuracy: 0.5362
# Epoch 7/300
# 14/14 [==============================] - 0s 3ms/step - loss: 1.2626 - accuracy: 0.5797
# Epoch 8/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9554 - accuracy: 0.7681
# Epoch 9/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9032 - accuracy: 0.7391
# Epoch 10/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8232 - accuracy: 0.7681
# Epoch 11/300
# 14/14 [==============================] - 0s 3ms/step - loss: 0.7174 - accuracy: 0.7681
# Epoch 12/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6614 - accuracy: 0.7826
# Epoch 13/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5437 - accuracy: 0.8696
# Epoch 14/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5578 - accuracy: 0.8406
# Epoch 15/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4708 - accuracy: 0.8841
# Epoch 16/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4621 - accuracy: 0.8696
# Epoch 17/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6319 - accuracy: 0.7826
# Epoch 18/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3765 - accuracy: 0.9420
# Epoch 19/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3242 - accuracy: 0.9275
# Epoch 20/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3274 - accuracy: 0.9420
# Epoch 21/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3072 - accuracy: 0.9275
# Epoch 22/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 0.8841
# Epoch 23/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2467 - accuracy: 0.9855
# Epoch 24/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2510 - accuracy: 0.9565
# Epoch 25/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.9420
# Epoch 26/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2903 - accuracy: 0.9275
# Epoch 27/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9420
# Epoch 28/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2129 - accuracy: 0.9710
# Epoch 29/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2060 - accuracy: 0.9420
# Epoch 30/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2926 - accuracy: 0.9275
# Epoch 31/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.9420
# Epoch 32/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2876 - accuracy: 0.9420
# Epoch 33/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2153 - accuracy: 0.9565
# Epoch 34/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2114 - accuracy: 0.9565
# Epoch 35/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.9420
# Epoch 36/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2538 - accuracy: 0.9275
# Epoch 37/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1164 - accuracy: 0.9855
# Epoch 38/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1212 - accuracy: 0.9710
# Epoch 39/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1778 - accuracy: 0.9855
# Epoch 40/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1987 - accuracy: 0.9275
# Epoch 41/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1139 - accuracy: 0.9710
# Epoch 42/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1768 - accuracy: 0.9565
# Epoch 43/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.9855
# Epoch 44/300
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0981 - accuracy: 0.9855
# Epoch 45/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0866 - accuracy: 0.9855
# Epoch 46/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1259 - accuracy: 0.9565
# Epoch 47/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0976 - accuracy: 0.9710
# Epoch 48/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1217 - accuracy: 0.9710
# Epoch 49/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1031 - accuracy: 0.9855
# Epoch 50/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0921 - accuracy: 0.9565
# Epoch 51/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1029 - accuracy: 0.9855
# Epoch 52/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1469 - accuracy: 0.9565
# Epoch 53/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0960 - accuracy: 0.9855
# Epoch 54/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1297 - accuracy: 0.9710
# Epoch 55/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1328 - accuracy: 0.9710
# Epoch 56/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1065 - accuracy: 0.9710
# Epoch 57/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.9710
# Epoch 58/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0853 - accuracy: 0.9855
# Epoch 59/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0553 - accuracy: 0.9855
# Epoch 60/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0796 - accuracy: 0.9710
# Epoch 61/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0911 - accuracy: 0.9275
# Epoch 62/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.9710
# Epoch 63/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0707 - accuracy: 0.9855
# Epoch 64/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0678 - accuracy: 0.9855
# Epoch 65/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0967 - accuracy: 0.9855
# Epoch 66/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9565
# Epoch 67/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0682 - accuracy: 0.9855
# Epoch 68/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0523 - accuracy: 0.9855
# Epoch 69/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9710
# Epoch 70/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0637 - accuracy: 1.0000
# Epoch 71/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 0.9710
# Epoch 72/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0636 - accuracy: 0.9855
# Epoch 73/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0835 - accuracy: 0.9710
# Epoch 74/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 75/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9855
# Epoch 76/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0793 - accuracy: 0.9710
# Epoch 77/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9855
# Epoch 78/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0627 - accuracy: 0.9855
# Epoch 79/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9855
# Epoch 80/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 81/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0489 - accuracy: 0.9855
# Epoch 82/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0568 - accuracy: 0.9855
# Epoch 83/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0773 - accuracy: 0.9710
# Epoch 84/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0553 - accuracy: 0.9710
# Epoch 85/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0495 - accuracy: 0.9855
# Epoch 86/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 87/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0596 - accuracy: 1.0000
# Epoch 88/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0856 - accuracy: 0.9710
# Epoch 89/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0458 - accuracy: 0.9855
# Epoch 90/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 91/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9710
# Epoch 92/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 93/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 94/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 95/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 96/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0489 - accuracy: 0.9855
# Epoch 97/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 98/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9710
# Epoch 99/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 100/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 101/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 102/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0483 - accuracy: 1.0000
# Epoch 103/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9855
# Epoch 104/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9855
# Epoch 105/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 106/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 1.0000
# Epoch 107/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 108/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9855
# Epoch 109/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 110/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 111/300
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0537 - accuracy: 0.9710
# Epoch 112/300
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0526 - accuracy: 0.9855
# Epoch 113/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9855
# Epoch 114/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9855
# Epoch 115/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 116/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0273 - accuracy: 1.0000
# Epoch 117/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9855
# Epoch 118/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 119/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 120/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0239 - accuracy: 0.9855
# Epoch 121/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 122/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 123/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 124/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 125/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 126/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0915 - accuracy: 0.9420
# Epoch 127/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 128/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 129/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 0.9855
# Epoch 130/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 131/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0426 - accuracy: 0.9855
# Epoch 132/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0569 - accuracy: 0.9710
# Epoch 133/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.9855
# Epoch 134/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 135/300
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 136/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0852 - accuracy: 0.9855
# Epoch 137/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 138/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0495 - accuracy: 1.0000
# Epoch 139/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9855
# Epoch 140/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 141/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9855
# Epoch 142/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 143/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 144/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 145/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9855
# Epoch 146/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9855
# Epoch 147/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 148/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 149/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 150/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 151/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0336 - accuracy: 0.9855
# Epoch 152/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 0.9855
# Epoch 153/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9855
# Epoch 154/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0539 - accuracy: 0.9855
# Epoch 155/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 156/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0273 - accuracy: 0.9855
# Epoch 157/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 158/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9710
# Epoch 159/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 0.9855
# Epoch 160/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9855
# Epoch 161/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 162/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9855
# Epoch 163/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 0.9855
# Epoch 164/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 165/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 166/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 167/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 168/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 169/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9855
# Epoch 170/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 171/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 172/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 0.9855
# Epoch 173/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 174/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0278 - accuracy: 0.9855
# Epoch 175/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 176/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 177/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0711 - accuracy: 0.9855
# Epoch 178/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 179/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 180/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 181/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 182/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9855
# Epoch 183/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 184/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 185/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9855
# Epoch 186/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 187/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 188/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 189/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 190/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 191/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 192/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0312 - accuracy: 0.9855
# Epoch 193/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9855
# Epoch 194/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 195/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 196/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 197/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0638 - accuracy: 0.9710
# Epoch 198/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0599 - accuracy: 0.9710
# Epoch 199/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 200/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 201/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 202/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 203/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 204/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 205/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 206/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 207/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 208/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 209/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 210/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 211/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 212/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 0.9710
# Epoch 213/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 214/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9855
# Epoch 215/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 216/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 217/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 218/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 219/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 220/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 221/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9855
# Epoch 222/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 223/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 224/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 225/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 226/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 227/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 228/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 229/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 230/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 231/300
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0864 - accuracy: 0.9855
# Epoch 232/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9855
# Epoch 233/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 234/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 0.9855
# Epoch 235/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 236/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.9855
# Epoch 237/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9855
# Epoch 238/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 239/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9855
# Epoch 240/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 241/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 242/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 243/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 244/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 245/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9855
# Epoch 246/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 0.9855
# Epoch 247/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 248/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9855
# Epoch 249/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 250/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 251/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 252/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 253/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 254/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 255/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 256/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 0.9855
# Epoch 257/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 258/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 259/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0557 - accuracy: 0.9710
# Epoch 260/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 261/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9855
# Epoch 262/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 263/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 264/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 265/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 266/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 0.9855
# Epoch 267/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 268/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 269/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 270/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9855
# Epoch 271/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 272/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9855
# Epoch 273/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 274/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 275/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 276/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 277/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0579 - accuracy: 0.9855
# Epoch 278/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9855
# Epoch 279/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 280/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 281/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 282/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 283/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0359 - accuracy: 0.9855
# Epoch 284/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 285/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 286/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 287/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 288/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 289/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 290/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 291/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 292/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 293/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 294/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9710
# Epoch 295/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9855
# Epoch 296/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 297/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 298/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 299/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 300/300
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000
# modelo creado

# %%
modelo=load_model("modelo_chatbot_pugs.h5")
intentos= json.loads(open("intenciones.json").read())
palabras = pickle.load(open("palabras.pkl","rb"))
classes = pickle.load(open("categorias.pkl","rb"))

# %%
def limpiar_conversacion(sentence):
    sentence_words=nltk.word_tokenize(sentence)
    sentence_words=sentence_words=[lematizar.stem(palabras.lower()) for palabras in sentence_words] 
    return sentence_words

def bow (sentence,palabras,show_details=True): 
    sentence_words=limpiar_conversacion(sentence)
    
    contenedor=[0]*len(palabras)
    
    for i in sentence_words:
        for j,w in enumerate(palabras):
            if w==i: 
                contenedor[j]=1
                if show_details:
                    print("encontrado: ",w)
    return (np.array(contenedor))

def predict_class(sentence,model):
    p = bow(sentence,palabras,show_details=False) 
    res = model.predict(np.array([p]))[0] 
    
    ERROR_THRESHOLD=0.25
    results= [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD] 
    results.sort(key=lambda x: x[1], reverse=True) 
    
    return_list = []    
    for r in results:   
        return_list.append({"intent": categorias[r[0]], "probability": str(r[1])})   
    print("print de return list: ", return_list) 
    return return_list



def get_response(ints,intenciones_json):
    tag= ints[0]["intent"]
    list_of_intents=intenciones_json["intenciones"] 
    
    for i  in list_of_intents: 
        if (i["etiqueta"]==tag):
            result= random.choice(i["respuestas"]) 
            break
    return result

def chatbot_response(text): 
    ints=predict_class(text,modelo) 
    res=get_response(ints,intenciones)
    return res

# %%
##Prueba
texto_us=""
print(" bienvenido, para salir escriba *listo*")
while texto_us!="listo":
    texto_us=input()
    res=chatbot_response(texto_us)
    print(res)
# Out:
#  bienvenido, para salir escriba *listo*
# hola
# 1/1 [==============================] - 0s 91ms/step
# print de return list:  [{'intent': 'saludos', 'probability': '0.99918646'}]
# GUAU GUAU!, me llamo PUGS! su sistema de ayuda para atencion en sus preguntas o dudas sobre el centro de atencion para su(s) mascota(s). En que te puedo ayudar?
# que servicios ofrecen?
# 1/1 [==============================] - 0s 22ms/step
# print de return list:  [{'intent': 'servicios', 'probability': '1.0'}]
# Ofrecemos los siguientes servicios:
# -Medicina Preventiva
# -Medicina General
#  -Medicina Especializada
#  -Cirugia General
#  -Cirugias Especializadas
#  -Acupuntura
#  -Cardiogramas
#  -Ultrasonidos
#  -Electrocardiograma
#  -Rayos X
#  -Endoscopia
#  -Laboratorios
#  -Urgencia
# y en que horarios atienden?
# 1/1 [==============================] - 0s 22ms/step
# print de return list:  [{'intent': 'horarios', 'probability': '1.0'}]
# Estamos abiertos de Lunes a Sabados de 6:00 a.m - 10:00 p.m y los Domingos de 6:00 a.m - 7:00 p.m
# donde estan ubicados?
# 1/1 [==============================] - 0s 22ms/step
# print de return list:  [{'intent': 'ubicacion', 'probability': '1.0'}]
# Nos encontramos ubicados en Chanis, Campo Limbergh, Casa H-49, Ciudad de Panama, Panama
#  En el siguiente link se muestra la ubicacion exacta: https://goo.gl/maps/tacZVtLWV5ENFv6W7
# muchas gracias
# 1/1 [==============================] - 0s 22ms/step
# print de return list:  [{'intent': 'agradecimientos', 'probability': '1.0'}]
# Ha sido todo un placer humano!
# listo
# 1/1 [==============================] - 0s 20ms/step
# print de return list:  [{'intent': 'sinrespuesta', 'probability': '0.8981332'}]
# ouh, no comprendo lo que me quieres decir humano :(. Puedes hacerme preguntas como:
# Horario
# Servicios
# Ubicacion
# Contacto

# %%
plt.plot(hist.history['accuracy'])
plt.title(' model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(hist.history['loss'])
plt.title(' model accuracy')
plt.ylabel('loss')
plt.xlabel('Epoch')

plt.show()

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               22016
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 8)                 520
#
# =================================================================
# Total params: 30,792
# Trainable params: 30,792
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ![flujograma.png](attachment:flujograma.png)
