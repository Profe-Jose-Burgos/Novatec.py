# %% [markdown]
# # NOVATEC.PY - HACKATHON SIC 2022-23

# %% [markdown]
# ## Chatbot - PUGS 2.0

# %%
import pickle
import nltk
import json
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
from nltk.stem import SnowballStemmer
import random

# %%
def guardar_json(datos):
    archivo = open("intenciones.json", "w")
    json.dump(datos, archivo, indent = 4)

# %%
biblioteca = {"intenciones":
              [
                  {"etiqueta":"saludos",
                   "patrones":["hola",
                               "hey",
                               "buenas",
                               "buenos dias",
                               "buenas noches",
                               "buenas tardes",
                               "hay alguien ahi?",
                               "que tal?"
                               "saludos",
                               "como estas?"
                              ],
                   "respuestas":["GUAU GUAU!, me llamo PUGS! su sistema de ayuda para atencion en sus preguntas o dudas sobre el centro de atencion para su(s) mascota(s). En que te puedo ayudar?"],
                   "contexto":[""]
                },
                  
                {"etiqueta":"despedidas",
                 "patrones":["adios",
                             "hasta luego",
                             "hasta pronto",
                             "hasta la proxima",
                             "chao",
                             "bye",
                             "nos vemos"
                             ],
                 "respuestas":["Gracias por consultarme humano!! Hasta Pronto :)",
                               "Hasta la proxima! Nos vemos!",
                               "Adios, espero haberte ayudado humano :)"],
                 "contexto":[""]
                },
                  
                  {"etiqueta":"agradecimientos",
                   "patrones":["gracias",
                               "gracias por tu ayuda",
                               "muchas gracias",
                               "gracias por tu tiempo",
                               "te lo agradezco",
                               "has sido de gran ayuda",
                               "mil gracias",
                               "genial",
                               "excelente",
                               "brutal",
                               "muy amable"
                              ],
                   "respuestas":["Espero haberte ayudado, eres un humano genial!!",
                                "De nada, estoy para ayudarte!",
                                "Ha sido todo un placer humano!",
                                "Gracias a usted por elegirnos!"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"servicios",
                   "patrones":["servicios",
                               "que servicios ofrecen?",
                               "de que servicios disponen?",
                               "realizan laboratorios?",
                               "realizan endoscopia?",
                               "medicina preventiva",
                               "medicina general",
                               "medicina especializada",
                               "ofrecen cirugias especializadas?",
                               "ofrecen cirugia general?",
                               "tienen servicios de acupuntura?",
                               "servicos de cardiograma",
                               "hacen ultrasonidos?",
                               "realizan electrocardiogramas?",
                               "hacen rayos x?",
                               "ofrecen servicios de urgencia?",
                               "que hacen?"
                              ],
                   "respuestas":["Ofrecemos los siguientes servicios:\n-Medicina Preventiva\n-Medicina General\n -Medicina Especializada\n -Cirugia General\n -Cirugias Especializadas\n -Acupuntura\n -Cardiogramas\n -Ultrasonidos\n -Electrocardiograma\n -Rayos X\n -Endoscopia\n -Laboratorios\n -Urgencia"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"horarios",
                   "patrones":["horario",
                               "que horario tienen?",
                               "a que hora atienden?",
                               "cual es su horario de atencion?",
                               "estan disponibles?",
                               "estan abiertos?",
                               "estan cerrados?",
                               "que dia atienden?",
                               "atienden?"
                              ],
                   "respuestas":["Estamos abiertos de Lunes a Sabados de 6:00 a.m - 10:00 p.m y los Domingos de 6:00 a.m - 7:00 p.m"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"ubicacion",
                   "patrones":["ubicacion",
                               "donde se encuentran ubicados?",
                               "en donde estan localizados?",
                               "Donde estan?",
                               "Donde los puedo encontrar?",
                               "Como puedo llegar?",
                               "podrian enviar la ubicacion?",
                               "localizacion",
                               "en que parte se encuentran ubicados?"
                              ],
                   "respuestas":["Nos encontramos ubicados en Chanis, Campo Limbergh, Casa H-49, Ciudad de Panama, Panama\n En el siguiente link se muestra la ubicacion exacta: https://goo.gl/maps/tacZVtLWV5ENFv6W7"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"contacto",
                   "patrones":["contacto",
                               "como los puedo contactar?",
                               "tiene algun numero de contacto?",
                               "tienen whatsapp?",
                               "tienen instagram?",
                               "tienen algun numero de telefono?"
                              ],
                   "respuestas":["Puedes contactarte directamente con nosotros al Whatsapp: +507 62840188 o a nuestro numero telefónico: 391-8357 / 391-8358\n Tambien nos puedes seguir en nuestro Instagram para no perderte de ninguna promocion!!: https://www.instagram.com/clinicavetpatasyhuellas/?hl=es"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"horario_cita",
                   "patrones":["cita",
                               "agendar",
                               "quiero agendar una cita",
                               "quisiera programar una cita",
                               "como puedo agendar una cita?",
                               "tramite de cita"
                              ],
                   "respuestas":["Tenemos los siguientes horarios disponibles para agendar su cita (escriba el codigo de la cita seguido de su nombre y numero de celular: ejem(H3 Luis Samaniego 6590-9090))\n H1. Lunes 8:00 a.m\n H2. Marte 10:00 a.m\n H3. Miercoles 8:00 a.m\n H4. Jueves 10:00 a.m\n H5. Viernes 8:00 a.m"],            
                   "contexto":[""]
                },
                  
                  {"etiqueta":"agendar_cita",
                   "patrones":["H1",
                               "H2",
                               "H3",
                               "H4",
                               "H5"
                              ],
                   "respuestas":["Gracias por confiar en nosotros. Tienes alguna otra duda?"],
                   "contexto":[""]
                },
                  
                  {"etiqueta":"sinrespuesta",
                   "patrones":[""],
                   "respuestas":["no se ha detectado respuesta. Puedes hacerme preguntas como:\nHorario \nServicios \nCitas \nUbicacion \nContacto",
                                 "ouh, no comprendo lo que me quieres decir humano :(. Puedes hacerme preguntas como:\nHorario \nServicios \nCitas \nUbicacion \nContacto",
                                 "lo siento, podrias decirlo de otro manera?, a veces me cuesta entender a los humanos. Puedes hacerme preguntas como:\nHorario \nServicios \nCitas \nUbicacion \nContacto"],
                   "contexto":[""]
                  }
              ]
    
            }

guardar_json(biblioteca)

# %%
palabras_ignoradas = ["?", "¿", "!", "¡", ",", ".", "|", "°", "*"]
archivo_json = open("intenciones.json").read()
intenciones = json.loads(archivo_json)

# %%
palabras = []
categorias = []
documentos = []

for intencion in intenciones["intenciones"]:
    for patron in intencion["patrones"]:
        w_token = nltk.word_tokenize(patron)
        palabras.extend(w_token)
        
        
        documentos.append((w_token, intencion["etiqueta"]))
        
        if intencion["etiqueta"] not in categorias:
            categorias.append(intencion["etiqueta"])

# %%
lematizar = SnowballStemmer('spanish')
palabras = [lematizar.stem(pal.lower()) for pal in palabras if pal not in palabras_ignoradas]

pickle.dump(palabras, open("palabras.pkl", "wb"))
pickle.dump(categorias, open("categorias.pkl", "wb"))

# %%
pickle.dump(palabras, open("palabras.pkl", "wb"))
pickle.dump(categorias, open("categorias.pkl", "wb"))

# %%
entrenamiento=[]
output_empty=[0]*len(categorias)

for doc in documentos:
    contenedor=[]
    patrones_pal=doc[0]
    patrones_pal=[lematizar.stem(palabra.lower()) for palabra in patrones_pal if palabra not in palabras_ignoradas ]
    
    for palabra in palabras:
        contenedor.append(1) if palabra in patrones_pal else contenedor.append(0)
        
    output_row=list(output_empty)
    output_row[categorias.index(doc[1])] = 1
    
    entrenamiento.append([contenedor, output_row])
    
entrenamiento=np.array(entrenamiento)
x_train = list(entrenamiento[:,0])
y_train = list(entrenamiento[:,1])
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_3424\1803794437.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   entrenamiento=np.array(entrenamiento)

# %%
modelo = Sequential()

modelo.add(Dense(128, input_shape=(len(x_train[0]),), activation='relu')) 
modelo.add(Dropout(0.5))
modelo.add(Dense(64,activation='relu')) 
modelo.add(Dropout(0.5))
modelo.add(Dense(len(y_train[0]),activation='softmax'))

sgd=SGD(learning_rate=0.01, weight_decay=1e-6,momentum=0.9,nesterov=True) 

modelo.compile(loss="categorical_crossentropy",optimizer=sgd,metrics=["accuracy"])

hist=modelo.fit(np.array(x_train),np.array(y_train),epochs=300,batch_size=5,verbose=1)
modelo.save("modelo_chatbot_pugs.h5",hist)
print("modelo creado")

#print("###############MODELO CREADO####################")
#reemplazar los nombres de la extensiones si es necesario
# Out:
# Epoch 1/300
# 16/16 [==============================] - 1s 3ms/step - loss: 2.3004 - accuracy: 0.1125
# Epoch 2/300
# 16/16 [==============================] - 0s 4ms/step - loss: 2.1261 - accuracy: 0.2000
# Epoch 3/300
# 16/16 [==============================] - 0s 3ms/step - loss: 2.0209 - accuracy: 0.2750
# Epoch 4/300
# 16/16 [==============================] - 0s 3ms/step - loss: 1.8660 - accuracy: 0.3500
# Epoch 5/300
# 16/16 [==============================] - 0s 3ms/step - loss: 1.7230 - accuracy: 0.4125
# Epoch 6/300
# 16/16 [==============================] - 0s 5ms/step - loss: 1.5989 - accuracy: 0.5000
# Epoch 7/300
# 16/16 [==============================] - 0s 6ms/step - loss: 1.3315 - accuracy: 0.5750
# Epoch 8/300
# 16/16 [==============================] - 0s 6ms/step - loss: 1.3183 - accuracy: 0.6000
# Epoch 9/300
# 16/16 [==============================] - 0s 4ms/step - loss: 1.1347 - accuracy: 0.6375
# Epoch 10/300
# 16/16 [==============================] - 0s 4ms/step - loss: 1.0791 - accuracy: 0.6500
# Epoch 11/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.8723 - accuracy: 0.7375
# Epoch 12/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.7959 - accuracy: 0.7625
# Epoch 13/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.7708 - accuracy: 0.8000
# Epoch 14/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.7191 - accuracy: 0.7875
# Epoch 15/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.7180 - accuracy: 0.7250
# Epoch 16/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5341 - accuracy: 0.8500
# Epoch 17/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5658 - accuracy: 0.9000
# Epoch 18/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5481 - accuracy: 0.8375
# Epoch 19/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4934 - accuracy: 0.8750
# Epoch 20/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4976 - accuracy: 0.8500
# Epoch 21/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3836 - accuracy: 0.9250
# Epoch 22/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3358 - accuracy: 0.9375
# Epoch 23/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3309 - accuracy: 0.9125
# Epoch 24/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3506 - accuracy: 0.9250
# Epoch 25/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3449 - accuracy: 0.8750
# Epoch 26/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3716 - accuracy: 0.9000
# Epoch 27/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2897 - accuracy: 0.9375
# Epoch 28/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2513 - accuracy: 0.9500
# Epoch 29/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2407 - accuracy: 0.9375
# Epoch 30/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.2859 - accuracy: 0.9125
# Epoch 31/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2086 - accuracy: 0.9375
# Epoch 32/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2170 - accuracy: 0.9750
# Epoch 33/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1728 - accuracy: 0.9750
# Epoch 34/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2397 - accuracy: 0.9375
# Epoch 35/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2171 - accuracy: 0.9625
# Epoch 36/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1728 - accuracy: 0.9625
# Epoch 37/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1799 - accuracy: 0.9500
# Epoch 38/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1662 - accuracy: 0.9625
# Epoch 39/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1851 - accuracy: 0.9625
# Epoch 40/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1332 - accuracy: 0.9625
# Epoch 41/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1646 - accuracy: 0.9625
# Epoch 42/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1876 - accuracy: 0.9750
# Epoch 43/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1536 - accuracy: 0.9500
# Epoch 44/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1498 - accuracy: 0.9500
# Epoch 45/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1225 - accuracy: 0.9875
# Epoch 46/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2030 - accuracy: 0.9250
# Epoch 47/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1769 - accuracy: 0.9375
# Epoch 48/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1062 - accuracy: 0.9875
# Epoch 49/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1664 - accuracy: 0.9500
# Epoch 50/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1597 - accuracy: 0.9625
# Epoch 51/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1206 - accuracy: 0.9750
# Epoch 52/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1462 - accuracy: 0.9375
# Epoch 53/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0975 - accuracy: 0.9750
# Epoch 54/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1267 - accuracy: 0.9625
# Epoch 55/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1036 - accuracy: 0.9750
# Epoch 56/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1313 - accuracy: 0.9875
# Epoch 57/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1583 - accuracy: 0.9500
# Epoch 58/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1576 - accuracy: 0.9625
# Epoch 59/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1964 - accuracy: 0.9500
# Epoch 60/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1239 - accuracy: 0.9625
# Epoch 61/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0951 - accuracy: 0.9750
# Epoch 62/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0913 - accuracy: 0.9750
# Epoch 63/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0714 - accuracy: 0.9875
# Epoch 64/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9875
# Epoch 65/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1014 - accuracy: 0.9750
# Epoch 66/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1238 - accuracy: 0.9375
# Epoch 67/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.9500
# Epoch 68/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0739 - accuracy: 0.9750
# Epoch 69/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0805 - accuracy: 0.9750
# Epoch 70/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1640 - accuracy: 0.9375
# Epoch 71/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0903 - accuracy: 0.9750
# Epoch 72/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0733 - accuracy: 0.9875
# Epoch 73/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0544 - accuracy: 0.9875
# Epoch 74/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.9625
# Epoch 75/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 0.9750
# Epoch 76/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1177 - accuracy: 0.9625
# Epoch 77/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9750
# Epoch 78/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0719 - accuracy: 0.9875
# Epoch 79/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0986 - accuracy: 0.9750
# Epoch 80/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0740 - accuracy: 0.9750
# Epoch 81/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1386 - accuracy: 0.9500
# Epoch 82/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0564 - accuracy: 0.9875
# Epoch 83/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0678 - accuracy: 0.9750
# Epoch 84/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1475 - accuracy: 0.9625
# Epoch 85/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0731 - accuracy: 0.9875
# Epoch 86/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 0.9875
# Epoch 87/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0917 - accuracy: 0.9625
# Epoch 88/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 89/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0857 - accuracy: 0.9625
# Epoch 90/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0704 - accuracy: 0.9750
# Epoch 91/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0584 - accuracy: 0.9875
# Epoch 92/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0661 - accuracy: 0.9875
# Epoch 93/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0467 - accuracy: 0.9875
# Epoch 94/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 95/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0506 - accuracy: 0.9875
# Epoch 96/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.9750
# Epoch 97/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9750
# Epoch 98/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0864 - accuracy: 0.9750
# Epoch 99/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0875 - accuracy: 0.9750
# Epoch 100/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 1.0000
# Epoch 101/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 0.9875
# Epoch 102/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 0.9875
# Epoch 103/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0613 - accuracy: 0.9750
# Epoch 104/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0826 - accuracy: 0.9750
# Epoch 105/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0573 - accuracy: 0.9875
# Epoch 106/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 107/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 108/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1006 - accuracy: 0.9500
# Epoch 109/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0851 - accuracy: 0.9750
# Epoch 110/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 0.9875
# Epoch 111/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9875
# Epoch 112/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0625 - accuracy: 0.9750
# Epoch 113/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0412 - accuracy: 0.9875
# Epoch 114/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 0.9875
# Epoch 115/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0871 - accuracy: 0.9625
# Epoch 116/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0423 - accuracy: 0.9875
# Epoch 117/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0431 - accuracy: 0.9875
# Epoch 118/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 119/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0794 - accuracy: 0.9750
# Epoch 120/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 121/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0618 - accuracy: 0.9875
# Epoch 122/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0307 - accuracy: 0.9875
# Epoch 123/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0602 - accuracy: 0.9875
# Epoch 124/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0490 - accuracy: 0.9875
# Epoch 125/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0297 - accuracy: 0.9875
# Epoch 126/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0467 - accuracy: 0.9875
# Epoch 127/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0628 - accuracy: 0.9750
# Epoch 128/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9875
# Epoch 129/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 0.9875
# Epoch 130/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 131/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 0.9875
# Epoch 132/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 133/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 0.9875
# Epoch 134/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 0.9875
# Epoch 135/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 136/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 137/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0606 - accuracy: 0.9875
# Epoch 138/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0470 - accuracy: 0.9750
# Epoch 139/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 140/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 141/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 0.9750
# Epoch 142/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 0.9875
# Epoch 143/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 144/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 145/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 0.9875
# Epoch 146/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0274 - accuracy: 0.9875
# Epoch 147/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0321 - accuracy: 0.9875
# Epoch 148/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0465 - accuracy: 0.9875
# Epoch 149/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 150/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0323 - accuracy: 0.9875
# Epoch 151/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 0.9875
# Epoch 152/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 153/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 0.9875
# Epoch 154/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 155/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 0.9875
# Epoch 156/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 157/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 158/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0456 - accuracy: 0.9875
# Epoch 159/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 160/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1214 - accuracy: 0.9750
# Epoch 161/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 162/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 0.9875
# Epoch 163/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.9875
# Epoch 164/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0338 - accuracy: 0.9875
# Epoch 165/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9875
# Epoch 166/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 0.9875
# Epoch 167/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0707 - accuracy: 0.9750
# Epoch 168/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9875
# Epoch 169/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 170/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0933 - accuracy: 0.9750
# Epoch 171/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 0.9875
# Epoch 172/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.9875
# Epoch 173/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0519 - accuracy: 0.9875
# Epoch 174/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 0.9875
# Epoch 175/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 176/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 177/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 178/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 179/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 180/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 181/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0360 - accuracy: 0.9875
# Epoch 182/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 0.9875
# Epoch 183/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 0.9875
# Epoch 184/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 0.9875
# Epoch 185/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 0.9875
# Epoch 186/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0438 - accuracy: 0.9750
# Epoch 187/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0323 - accuracy: 0.9875
# Epoch 188/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9875
# Epoch 189/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 190/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 191/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 192/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 193/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 194/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0574 - accuracy: 0.9875
# Epoch 195/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 196/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 197/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 0.9875
# Epoch 198/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 199/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.9875
# Epoch 200/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 0.9875
# Epoch 201/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 0.9875
# Epoch 202/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 203/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 0.9875
# Epoch 204/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 0.9750
# Epoch 205/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 206/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 207/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 208/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 209/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 210/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 211/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 212/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 213/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 214/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 215/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 216/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9875
# Epoch 217/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9875
# Epoch 218/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0381 - accuracy: 0.9875
# Epoch 219/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 220/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 221/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 0.9875
# Epoch 222/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0333 - accuracy: 0.9875
# Epoch 223/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9875
# Epoch 224/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9875
# Epoch 225/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0528 - accuracy: 0.9750
# Epoch 226/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0392 - accuracy: 0.9875
# Epoch 227/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 228/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0414 - accuracy: 0.9750
# Epoch 229/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 230/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 0.9875
# Epoch 231/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9875
# Epoch 232/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 233/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0320 - accuracy: 0.9875
# Epoch 234/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 235/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 236/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 237/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 238/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 239/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 240/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 241/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.9875
# Epoch 242/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 0.9875
# Epoch 243/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0422 - accuracy: 0.9750
# Epoch 244/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 245/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0604 - accuracy: 0.9875
# Epoch 246/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0828 - accuracy: 0.9750
# Epoch 247/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 248/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 249/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 0.9875
# Epoch 250/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 251/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0304 - accuracy: 0.9875
# Epoch 252/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 0.9875
# Epoch 253/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 0.9875
# Epoch 254/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 0.9875
# Epoch 255/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 0.9875
# Epoch 256/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 257/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 258/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 0.9875
# Epoch 259/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 0.9875
# Epoch 260/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 0.9875
# Epoch 261/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0408 - accuracy: 0.9875
# Epoch 262/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 263/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 0.9875
# Epoch 264/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 265/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 266/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 0.9875
# Epoch 267/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 268/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0563 - accuracy: 0.9875
# Epoch 269/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 270/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 271/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 272/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 273/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 274/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 275/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 276/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 277/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 278/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 279/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 280/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 281/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 282/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 283/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 0.9875
# Epoch 284/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 285/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 286/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 287/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 288/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 289/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 290/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 291/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 292/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.9875
# Epoch 293/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 294/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 295/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 296/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 297/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 298/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 299/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0504 - accuracy: 0.9875
# Epoch 300/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 1.0000
# modelo creado

# %%
modelo=load_model("modelo_chatbot_pugs.h5")
intentos= json.loads(open("intenciones.json").read())
palabras = pickle.load(open("palabras.pkl","rb"))
classes = pickle.load(open("categorias.pkl","rb"))

# %%
def expresion_regular(texto3):
    import re
    val = True
    
    while val == True:
        #print("Perfecto! Ingrese su nombre y numero de celular con el siguiente formato:(nombre xxxx-xxxx))"
        #text = input()
        regex_nombre = u'\w+[a-z]'
        regex_numero = u'\d\d\d\d\-\d\d\d\d'
        res_nom = re.findall(regex_nombre, texto3)
        res_cel = re.findall(regex_numero, texto3)

        if len(res_nom) == 0:
            r = "Uy, parece no ingresaste tu nombre :( vuelve a intentarlo!"
            texto3 = input()
            val = True

        elif len(res_cel) == 0:
            r = "Uy, parece no ingresaste tu numero de celular :( vuelve a intentarlo!"
            texto3 = input()
            val = True

        else:

            r= str("Su cita ha sido correctamente agendada\t" +res_nom[0])
            val = False
    return r

# %%
def limpiar_conversacion(sentence):
    sentence_words=nltk.word_tokenize(sentence)
    sentence_words=sentence_words=[lematizar.stem(palabras.lower()) for palabras in sentence_words] 
    return sentence_words

def bow (sentence,palabras,show_details=True): 
    sentence_words=limpiar_conversacion(sentence)
    
    contenedor=[0]*len(palabras)
    
    for i in sentence_words:
        for j,w in enumerate(palabras):
            if w==i: 
                contenedor[j]=1
                if show_details:
                    print("encontrado: ",w)
    return (np.array(contenedor))

def predict_class(sentence,model):
    p = bow(sentence,palabras,show_details=False) 
    res = model.predict(np.array([p]))[0] 
    
    ERROR_THRESHOLD=0.25
    results= [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD] 
    results.sort(key=lambda x: x[1], reverse=True) 
    
    return_list = []    
    for r in results:   
        return_list.append({"intent": categorias[r[0]], "probability": str(r[1])})   
    print("print de return list: ", return_list) 
    return return_list



def get_response(ints,intenciones_json):
    tag= ints[0]["intent"]
    list_of_intents=intenciones_json["intenciones"] 
    
    for i  in list_of_intents:
        if (i["etiqueta"]==tag and tag == "agendar_cita"):
            result= expresion_regular(texto_us)
            break
        elif (i["etiqueta"]==tag):
            result= random.choice(i["respuestas"]) 
            break
    return result

def chatbot_response(text): 
    ints=predict_class(text,modelo) 
    res=get_response(ints,intenciones)
    return res

# %%
##Prueba
texto_us=""
print(" bienvenido, para salir escriba *listo*")
while texto_us!="listo":
    texto_us=input()
    res=chatbot_response(texto_us)
    print(res)
# Out:
#  bienvenido, para salir escriba *listo*
# quiero cita
# 1/1 [==============================] - 0s 31ms/step
# print de return list:  [{'intent': 'horario_cita', 'probability': '1.0'}]
# Tenemos los siguientes horarios disponibles para agendar su cita(escriba el codigo de la cita seguido de su nombre y numero de celular: ejm(H3 Luis Samaniego 6590-9090))
#  H1. Lunes 8:00 a.m
#  H2. Marte 10:00 a.m
#  H3. Miercoles 8:00 a.m
#  H4. Jueves 10:00 a.m
#  H5. Viernes 8:00 a.m
# H5 Jonatan 6767-9090
# 1/1 [==============================] - 0s 27ms/step
# print de return list:  [{'intent': 'agendar_cita', 'probability': '0.99922574'}]
# Su cita ha sido correctamente agendada Jonatan
# Lo estaremos llamando al número 6767-9090 para recordarle su cita!
# None
# H3 Luis samaniego 7878-9090
# 1/1 [==============================] - 0s 26ms/step
# print de return list:  [{'intent': 'agendar_cita', 'probability': '0.99916196'}]
# Su cita ha sido correctamente agendada Luis
# Lo estaremos llamando al número 7878-9090 para recordarle su cita!
# None
# listo
# 1/1 [==============================] - 0s 26ms/step
# print de return list:  [{'intent': 'sinrespuesta', 'probability': '0.8454647'}]
# no se ha detectado respuesta. Puedes hacerme preguntas como:
# Horario
# Servicios
# Citas
# Ubicacion
# Contacto

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hist.history['accuracy'])
plt.title(' model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(hist.history['loss'])
plt.title(' model accuracy')
plt.ylabel('loss')
plt.xlabel('Epoch')

plt.show()

# %%
modelo.summary()

# %% [markdown]
# ![flujograma.png](attachment:flujograma.png)
