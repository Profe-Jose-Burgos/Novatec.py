# %% [markdown]
# # NOVATEC.PY - HACKATHON SIC 2022-23

# %% [markdown]
# ## Chatbot - PUGS 2.0

# %%
import pickle
import nltk
import json
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
from nltk.stem import SnowballStemmer
import random

# %%
def guardar_json(datos):
    archivo = open("intenciones.json", "w")
    json.dump(datos, archivo, indent = 4)

# %%
biblioteca = {"intenciones":
              [
                  {"etiqueta":"saludos",
                   "patrones":["hola",
                               "hey",
                               "buenas",
                               "buenos dias",
                               "buenas noches",
                               "buenas tardes",
                               "hay alguien ahi?",
                               "que tal?"
                               "saludos",
                               "como estas?"
                              ],
                   "respuestas":["GUAU GUAU!, me llamo PUGS! su sistema de ayuda para atencion en sus preguntas o dudas sobre el centro de atencion para su(s) mascota(s). En que te puedo ayudar?"],
                   "contexto":[""]
                },
                  
                {"etiqueta":"despedidas",
                 "patrones":["adios",
                             "hasta luego",
                             "hasta pronto",
                             "hasta la proxima",
                             "chao",
                             "bye",
                             "nos vemos"
                             ],
                 "respuestas":["Gracias por consultarme humano!! Hasta Pronto :)",
                               "Hasta la proxima! Nos vemos!",
                               "Adios, espero haberte ayudado humano :)"],
                 "contexto":[""]
                },
                  
                  {"etiqueta":"agradecimientos",
                   "patrones":["gracias",
                               "gracias por tu ayuda",
                               "muchas gracias",
                               "gracias por tu tiempo",
                               "te lo agradezco",
                               "has sido de gran ayuda",
                               "mil gracias",
                               "genial",
                               "excelente",
                               "brutal",
                               "muy amable"
                              ],
                   "respuestas":["Espero haberte ayudado, eres un humano genial!!",
                                "De nada, estoy para ayudarte!",
                                "Ha sido todo un placer humano!",
                                "Gracias a usted por elegirnos!"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"servicios",
                   "patrones":["servicios",
                               "que servicios ofrecen?",
                               "de que servicios disponen?",
                               "realizan laboratorios?",
                               "realizan endoscopia?",
                               "medicina preventiva",
                               "medicina general",
                               "medicina especializada",
                               "ofrecen cirugias especializadas?",
                               "ofrecen cirugia general?",
                               "tienen servicios de acupuntura?",
                               "servicos de cardiograma",
                               "hacen ultrasonidos?",
                               "realizan electrocardiogramas?",
                               "hacen rayos x?",
                               "ofrecen servicios de urgencia?",
                               "que hacen?"
                              ],
                   "respuestas":["Ofrecemos los siguientes servicios:\n-Medicina Preventiva\n-Medicina General\n -Medicina Especializada\n -Cirugia General\n -Cirugias Especializadas\n -Acupuntura\n -Cardiogramas\n -Ultrasonidos\n -Electrocardiograma\n -Rayos X\n -Endoscopia\n -Laboratorios\n -Urgencia"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"horarios",
                   "patrones":["horario",
                               "que horario tienen?",
                               "a que hora atienden?",
                               "cual es su horario de atencion?",
                               "estan disponibles?",
                               "estan abiertos?",
                               "estan cerrados?",
                               "que dia atienden?",
                               "atienden?"
                              ],
                   "respuestas":["Estamos abiertos de Lunes a Sabados de 6:00 a.m - 10:00 p.m y los Domingos de 6:00 a.m - 7:00 p.m"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"ubicacion",
                   "patrones":["ubicacion",
                               "donde se encuentran ubicados?",
                               "en donde estan localizados?",
                               "Donde estan?",
                               "Donde los puedo encontrar?",
                               "Como puedo llegar?",
                               "podrian enviar la ubicacion?",
                               "localizacion",
                               "en que parte se encuentran ubicados?"
                              ],
                   "respuestas":["Nos encontramos ubicados en Chanis, Campo Limbergh, Casa H-49, Ciudad de Panama, Panama\n En el siguiente link se muestra la ubicacion exacta: https://goo.gl/maps/tacZVtLWV5ENFv6W7"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"contacto",
                   "patrones":["contacto",
                               "como los puedo contactar?",
                               "tiene algun numero de contacto?",
                               "tienen whatsapp?",
                               "tienen instagram?",
                               "tienen algun numero de telefono?"
                              ],
                   "respuestas":["Puedes contactarte directamente con nosotros al Whatsapp: +507 62840188 o a nuestro numero telefónico: 391-8357 / 391-8358\n Tambien nos puedes seguir en nuestro Instagram para no perderte de ninguna promocion!!: https://www.instagram.com/clinicavetpatasyhuellas/?hl=es"],
                   "contexto":[""]         
                  },
                  
                  {"etiqueta":"horario_cita",
                   "patrones":["cita",
                               "agendar",
                               "quiero agendar una cita",
                               "quisiera programar una cita",
                               "como puedo agendar una cita?",
                               "tramite de cita"
                              ],
                   "respuestas":["Tenemos los siguientes horarios disponibles para agendar su cita(escriba el codigo de la cita que desee)\n H1. Lunes 8:00 a.m\n H2. Marte 10:00 a.m\n H3. Miercoles 8:00 a.m\n H4. Jueves 10:00 a.m\n H5. Viernes 8:00 a.m"],            
                   "contexto":[""]
                },
                  
                  {"etiqueta":"agendar_cita",
                   "patrones":["H1",
                               "H2",
                               "H3",
                               "H4",
                               "H5"
                              ],
                   "respuestas":["Gracias por confiar en nosotros. Tienes alguna otra duda?"],
                   "contexto":[""]
                },
                  
                  {"etiqueta":"sinrespuesta",
                   "patrones":[""],
                   "respuestas":["no se ha detectado respuesta. Puedes hacerme preguntas como:\nHorario \nServicios \nCitas \nUbicacion \nContacto",
                                 "ouh, no comprendo lo que me quieres decir humano :(. Puedes hacerme preguntas como:\nHorario \nServicios \nCitas \nUbicacion \nContacto",
                                 "lo siento, podrias decirlo de otro manera?, a veces me cuesta entender a los humanos. Puedes hacerme preguntas como:\nHorario \nServicios \nCitas \nUbicacion \nContacto"],
                   "contexto":[""]
                  }
              ]
    
            }

guardar_json(biblioteca)

# %%
palabras_ignoradas = ["?", "¿", "!", "¡", ",", ".", "|", "°", "*"]
archivo_json = open("intenciones.json").read()
intenciones = json.loads(archivo_json)

# %%
palabras = []
categorias = []
documentos = []

for intencion in intenciones["intenciones"]:
    for patron in intencion["patrones"]:
        w_token = nltk.word_tokenize(patron)
        palabras.extend(w_token)
        
        
        documentos.append((w_token, intencion["etiqueta"]))
        
        if intencion["etiqueta"] not in categorias:
            categorias.append(intencion["etiqueta"])

# %%
lematizar = SnowballStemmer('spanish')
palabras = [lematizar.stem(pal.lower()) for pal in palabras if pal not in palabras_ignoradas]

pickle.dump(palabras, open("palabras.pkl", "wb"))
pickle.dump(categorias, open("categorias.pkl", "wb"))

# %%
pickle.dump(palabras, open("palabras.pkl", "wb"))
pickle.dump(categorias, open("categorias.pkl", "wb"))

# %%
entrenamiento=[]
output_empty=[0]*len(categorias)

for doc in documentos:
    contenedor=[]
    patrones_pal=doc[0]
    patrones_pal=[lematizar.stem(palabra.lower()) for palabra in patrones_pal if palabra not in palabras_ignoradas ]
    
    for palabra in palabras:
        contenedor.append(1) if palabra in patrones_pal else contenedor.append(0)
        
    output_row=list(output_empty)
    output_row[categorias.index(doc[1])] = 1
    
    entrenamiento.append([contenedor, output_row])
    
entrenamiento=np.array(entrenamiento)
x_train = list(entrenamiento[:,0])
y_train = list(entrenamiento[:,1])
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_9924\1803794437.py:17: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   entrenamiento=np.array(entrenamiento)

# %%
modelo = Sequential()

modelo.add(Dense(128, input_shape=(len(x_train[0]),), activation='relu')) 
modelo.add(Dropout(0.5))
modelo.add(Dense(64,activation='relu')) 
modelo.add(Dropout(0.5))
modelo.add(Dense(len(y_train[0]),activation='softmax'))

sgd=SGD(learning_rate=0.01, weight_decay=1e-6,momentum=0.9,nesterov=True) 

modelo.compile(loss="categorical_crossentropy",optimizer=sgd,metrics=["accuracy"])

hist=modelo.fit(np.array(x_train),np.array(y_train),epochs=300,batch_size=5,verbose=1)
modelo.save("modelo_chatbot_pugs.h5",hist)
print("modelo creado")

#print("###############MODELO CREADO####################")
#reemplazar los nombres de la extensiones si es necesario
# Out:
# Epoch 1/300
# 16/16 [==============================] - 2s 4ms/step - loss: 2.3295 - accuracy: 0.0750
# Epoch 2/300
# 16/16 [==============================] - 0s 3ms/step - loss: 2.1403 - accuracy: 0.2250
# Epoch 3/300
# 16/16 [==============================] - 0s 4ms/step - loss: 1.9293 - accuracy: 0.3125
# Epoch 4/300
# 16/16 [==============================] - 0s 5ms/step - loss: 1.8399 - accuracy: 0.3375
# Epoch 5/300
# 16/16 [==============================] - 0s 5ms/step - loss: 1.6663 - accuracy: 0.4500
# Epoch 6/300
# 16/16 [==============================] - 0s 4ms/step - loss: 1.4743 - accuracy: 0.5125
# Epoch 7/300
# 16/16 [==============================] - 0s 5ms/step - loss: 1.4664 - accuracy: 0.4875
# Epoch 8/300
# 16/16 [==============================] - 0s 6ms/step - loss: 1.2905 - accuracy: 0.6500
# Epoch 9/300
# 16/16 [==============================] - 0s 6ms/step - loss: 1.0893 - accuracy: 0.6500
# Epoch 10/300
# 16/16 [==============================] - 0s 5ms/step - loss: 1.0542 - accuracy: 0.7000
# Epoch 11/300
# 16/16 [==============================] - 0s 4ms/step - loss: 1.0465 - accuracy: 0.6750
# Epoch 12/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.9214 - accuracy: 0.7000
# Epoch 13/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.7633 - accuracy: 0.7625
# Epoch 14/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.7658 - accuracy: 0.7500
# Epoch 15/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.8621 - accuracy: 0.6500
# Epoch 16/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.7158 - accuracy: 0.7875
# Epoch 17/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5716 - accuracy: 0.8500
# Epoch 18/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5990 - accuracy: 0.8125
# Epoch 19/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5732 - accuracy: 0.8500
# Epoch 20/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4295 - accuracy: 0.9250
# Epoch 21/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5306 - accuracy: 0.8500
# Epoch 22/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4300 - accuracy: 0.9000
# Epoch 23/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4329 - accuracy: 0.8875
# Epoch 24/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4849 - accuracy: 0.8500
# Epoch 25/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3028 - accuracy: 0.9375
# Epoch 26/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4936 - accuracy: 0.8125
# Epoch 27/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3883 - accuracy: 0.9500
# Epoch 28/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3412 - accuracy: 0.9375
# Epoch 29/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3433 - accuracy: 0.9250
# Epoch 30/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2831 - accuracy: 0.9375
# Epoch 31/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.2591 - accuracy: 0.9500
# Epoch 32/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3359 - accuracy: 0.9000
# Epoch 33/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3033 - accuracy: 0.9375
# Epoch 34/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2101 - accuracy: 0.9625
# Epoch 35/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.2271 - accuracy: 0.9375
# Epoch 36/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.2073 - accuracy: 0.9625
# Epoch 37/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1472 - accuracy: 0.9750
# Epoch 38/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1791 - accuracy: 0.9750
# Epoch 39/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1528 - accuracy: 0.9750
# Epoch 40/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1596 - accuracy: 0.9625
# Epoch 41/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1962 - accuracy: 0.9500
# Epoch 42/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2663 - accuracy: 0.9375
# Epoch 43/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1777 - accuracy: 0.9750
# Epoch 44/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1379 - accuracy: 0.9750
# Epoch 45/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1809 - accuracy: 0.9625
# Epoch 46/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2071 - accuracy: 0.9375
# Epoch 47/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1362 - accuracy: 0.9625
# Epoch 48/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1199 - accuracy: 0.9750
# Epoch 49/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1461 - accuracy: 0.9625
# Epoch 50/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1153 - accuracy: 0.9750
# Epoch 51/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1019 - accuracy: 0.9750
# Epoch 52/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1373 - accuracy: 0.9875
# Epoch 53/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 0.9875
# Epoch 54/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.9500
# Epoch 55/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0978 - accuracy: 0.9875
# Epoch 56/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1116 - accuracy: 0.9750
# Epoch 57/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0976 - accuracy: 0.9750
# Epoch 58/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1060 - accuracy: 0.9875
# Epoch 59/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1028 - accuracy: 0.9875
# Epoch 60/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0828 - accuracy: 0.9875
# Epoch 61/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0967 - accuracy: 0.9750
# Epoch 62/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0886 - accuracy: 0.9750
# Epoch 63/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0648 - accuracy: 0.9875
# Epoch 64/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1100 - accuracy: 0.9625
# Epoch 65/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0728 - accuracy: 0.9750
# Epoch 66/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0738 - accuracy: 0.9750
# Epoch 67/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.1543 - accuracy: 0.9625
# Epoch 68/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0780 - accuracy: 0.9875
# Epoch 69/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1093 - accuracy: 0.9875
# Epoch 70/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1351 - accuracy: 0.9750
# Epoch 71/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1044 - accuracy: 0.9750
# Epoch 72/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1379 - accuracy: 0.9500
# Epoch 73/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0902 - accuracy: 0.9750
# Epoch 74/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1039 - accuracy: 0.9625
# Epoch 75/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0972 - accuracy: 0.9625
# Epoch 76/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0775 - accuracy: 0.9875
# Epoch 77/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0610 - accuracy: 0.9750
# Epoch 78/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0976 - accuracy: 0.9875
# Epoch 79/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1073 - accuracy: 0.9750
# Epoch 80/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0666 - accuracy: 0.9875
# Epoch 81/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1290 - accuracy: 0.9750
# Epoch 82/300
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0553 - accuracy: 0.9875
# Epoch 83/300
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0673 - accuracy: 0.9750
# Epoch 84/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0605 - accuracy: 0.9875
# Epoch 85/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0843 - accuracy: 0.9750
# Epoch 86/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0819 - accuracy: 1.0000
# Epoch 87/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0463 - accuracy: 0.9875
# Epoch 88/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0603 - accuracy: 0.9875
# Epoch 89/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0516 - accuracy: 0.9750
# Epoch 90/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0548 - accuracy: 0.9750
# Epoch 91/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0979 - accuracy: 1.0000
# Epoch 92/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0385 - accuracy: 0.9875
# Epoch 93/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0981 - accuracy: 0.9750
# Epoch 94/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0457 - accuracy: 0.9875
# Epoch 95/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1232 - accuracy: 0.9750
# Epoch 96/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0783 - accuracy: 0.9750
# Epoch 97/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0519 - accuracy: 0.9875
# Epoch 98/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0603 - accuracy: 0.9750
# Epoch 99/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0483 - accuracy: 0.9875
# Epoch 100/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0446 - accuracy: 0.9875
# Epoch 101/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 102/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0443 - accuracy: 1.0000
# Epoch 103/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0449 - accuracy: 0.9875
# Epoch 104/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 1.0000
# Epoch 105/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 106/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.9875
# Epoch 107/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 0.9875
# Epoch 108/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0748 - accuracy: 0.9875
# Epoch 109/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 0.9875
# Epoch 110/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 111/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 0.9875
# Epoch 112/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0572 - accuracy: 0.9875
# Epoch 113/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 114/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0508 - accuracy: 0.9875
# Epoch 115/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 0.9875
# Epoch 116/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 0.9875
# Epoch 117/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 0.9875
# Epoch 118/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0423 - accuracy: 0.9875
# Epoch 119/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0810 - accuracy: 0.9625
# Epoch 120/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0479 - accuracy: 0.9875
# Epoch 121/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0488 - accuracy: 0.9750
# Epoch 122/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 0.9875
# Epoch 123/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0678 - accuracy: 0.9875
# Epoch 124/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0527 - accuracy: 0.9875
# Epoch 125/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0994 - accuracy: 0.9875
# Epoch 126/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0689 - accuracy: 0.9750
# Epoch 127/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 128/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1756 - accuracy: 0.9625
# Epoch 129/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0638 - accuracy: 0.9875
# Epoch 130/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0407 - accuracy: 0.9875
# Epoch 131/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0434 - accuracy: 0.9875
# Epoch 132/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 133/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0499 - accuracy: 0.9875
# Epoch 134/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0517 - accuracy: 0.9875
# Epoch 135/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0479 - accuracy: 0.9750
# Epoch 136/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 137/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 138/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0339 - accuracy: 0.9875
# Epoch 139/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 140/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 141/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 142/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 143/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9875
# Epoch 144/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 145/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 146/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 0.9875
# Epoch 147/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 148/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9875
# Epoch 149/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 150/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0382 - accuracy: 0.9875
# Epoch 151/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 152/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 0.9875
# Epoch 153/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 154/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0550 - accuracy: 0.9875
# Epoch 155/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 156/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0251 - accuracy: 0.9875
# Epoch 157/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 158/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1176 - accuracy: 0.9750
# Epoch 159/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 160/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 161/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0685 - accuracy: 0.9750
# Epoch 162/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0879 - accuracy: 0.9875
# Epoch 163/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 164/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.9625
# Epoch 165/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0424 - accuracy: 1.0000
# Epoch 166/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9625
# Epoch 167/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0400 - accuracy: 0.9875
# Epoch 168/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0402 - accuracy: 0.9875
# Epoch 169/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 170/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 171/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 0.9875
# Epoch 172/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 0.9875
# Epoch 173/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 174/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0523 - accuracy: 1.0000
# Epoch 175/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 176/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 177/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 0.9875
# Epoch 178/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0847 - accuracy: 0.9875
# Epoch 179/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0407 - accuracy: 0.9875
# Epoch 180/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 181/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0686 - accuracy: 0.9750
# Epoch 182/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 183/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0428 - accuracy: 0.9875
# Epoch 184/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 185/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 186/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 187/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0534 - accuracy: 0.9750
# Epoch 188/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 0.9750
# Epoch 189/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 190/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 191/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9875
# Epoch 192/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 0.9875
# Epoch 193/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 0.9875
# Epoch 194/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 195/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 0.9875
# Epoch 196/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9875
# Epoch 197/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0514 - accuracy: 0.9875
# Epoch 198/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 0.9875
# Epoch 199/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9875
# Epoch 200/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 201/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 202/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9875
# Epoch 203/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 0.9875
# Epoch 204/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0536 - accuracy: 0.9625
# Epoch 205/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0344 - accuracy: 0.9875
# Epoch 206/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0524 - accuracy: 0.9750
# Epoch 207/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 208/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 209/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9750
# Epoch 210/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 211/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9750
# Epoch 212/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9875
# Epoch 213/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0557 - accuracy: 0.9875
# Epoch 214/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9875
# Epoch 215/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0523 - accuracy: 0.9875
# Epoch 216/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 217/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 0.9875
# Epoch 218/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 219/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 0.9875
# Epoch 220/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0638 - accuracy: 0.9750
# Epoch 221/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.9875
# Epoch 222/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0750 - accuracy: 0.9750
# Epoch 223/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 0.9875
# Epoch 224/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 225/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0219 - accuracy: 0.9875
# Epoch 226/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 227/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0447 - accuracy: 0.9875
# Epoch 228/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 229/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 230/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 231/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 232/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 233/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 0.9875
# Epoch 234/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0232 - accuracy: 0.9875
# Epoch 235/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 0.9875
# Epoch 236/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 237/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0554 - accuracy: 0.9750
# Epoch 238/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0292 - accuracy: 0.9875
# Epoch 239/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 240/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 241/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 242/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 243/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 0.9875
# Epoch 244/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0533 - accuracy: 0.9875
# Epoch 245/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 246/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9875
# Epoch 247/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 248/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 249/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 250/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 251/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 252/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0369 - accuracy: 0.9875
# Epoch 253/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0395 - accuracy: 0.9750
# Epoch 254/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 255/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0334 - accuracy: 0.9875
# Epoch 256/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 257/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0617 - accuracy: 0.9875
# Epoch 258/300
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 259/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 260/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 261/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0455 - accuracy: 0.9875
# Epoch 262/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0355 - accuracy: 0.9875
# Epoch 263/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0285 - accuracy: 0.9875
# Epoch 264/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 265/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 0.9875
# Epoch 266/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 267/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 0.9875
# Epoch 268/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0192 - accuracy: 0.9875
# Epoch 269/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0357 - accuracy: 0.9875
# Epoch 270/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 271/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 0.9875
# Epoch 272/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 273/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9875
# Epoch 274/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9875
# Epoch 275/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 276/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 277/300
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 278/300
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 279/300
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 280/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 281/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 282/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 283/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 284/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 0.9875
# Epoch 285/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 286/300
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 287/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 288/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 0.9875
# Epoch 289/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 290/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 291/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 292/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 0.9875
# Epoch 293/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 294/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 295/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 0.9875
# Epoch 296/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 297/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 298/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 299/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 300/300
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# modelo creado

# %%
modelo=load_model("modelo_chatbot_pugs.h5")
intentos= json.loads(open("intenciones.json").read())
palabras = pickle.load(open("palabras.pkl","rb"))
classes = pickle.load(open("categorias.pkl","rb"))

# %%
def expresion_regular():
    import re
    val = True
    
    while val == True:
        print("Perfecto! Ingrese su nombre y numero de celular con el siguiente formato:(nombre xxxx-xxxx)")
        text = input()
        regex_nombre = u'\w+[a-z]'
        regex_numero = u'\d\d\d\d\-\d\d\d\d'
        res_nom = re.findall(regex_nombre, text)
        res_cel = re.findall(regex_numero, text)

        if len(res_nom) == 0:
            print("Uy, parece no ingresaste tu nombre :( vuelve a intentarlo!")
            val = True

        elif len(res_cel) == 0:
            print("Uy, parece no ingresaste tu numero de celular :( vuelve a intentarlo!")
            val = True

        else:

            r=(print("Su cita ha sido correctamente agendada", res_nom[0], "\nLo estaremos llamando al número",res_cel[0], "para recordarle su cita!"))
            val = False
    return r

# %%
def limpiar_conversacion(sentence):
    sentence_words=nltk.word_tokenize(sentence)
    sentence_words=sentence_words=[lematizar.stem(palabras.lower()) for palabras in sentence_words] 
    return sentence_words

def bow (sentence,palabras,show_details=True): 
    sentence_words=limpiar_conversacion(sentence)
    
    contenedor=[0]*len(palabras)
    
    for i in sentence_words:
        for j,w in enumerate(palabras):
            if w==i: 
                contenedor[j]=1
                if show_details:
                    print("encontrado: ",w)
    return (np.array(contenedor))

def predict_class(sentence,model):
    p = bow(sentence,palabras,show_details=False) 
    res = model.predict(np.array([p]))[0] 
    
    ERROR_THRESHOLD=0.25
    results= [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD] 
    results.sort(key=lambda x: x[1], reverse=True) 
    
    return_list = []    
    for r in results:   
        return_list.append({"intent": categorias[r[0]], "probability": str(r[1])})   
    print("print de return list: ", return_list) 
    return return_list



def get_response(ints,intenciones_json):
    tag= ints[0]["intent"]
    list_of_intents=intenciones_json["intenciones"] 
    
    for i  in list_of_intents:
        if (i["etiqueta"]==tag and tag == "agendar_cita"):
            result= expresion_regular()
            break
        elif (i["etiqueta"]==tag):
            result= random.choice(i["respuestas"]) 
            break
    return result

def chatbot_response(text): 
    ints=predict_class(text,modelo) 
    res=get_response(ints,intenciones)
    return res

# %%
##Prueba
texto_us=""
print(" bienvenido, para salir escriba *listo*")
while texto_us!="listo":
    texto_us=input()
    res=chatbot_response(texto_us)
    print(res)
# Out:
#  bienvenido, para salir escriba *listo*
# hla
# 1/1 [==============================] - 0s 294ms/step
# print de return list:  [{'intent': 'sinrespuesta', 'probability': '0.8810606'}]
# ouh, no comprendo lo que me quieres decir humano :(. Puedes hacerme preguntas como:
# Horario
# Servicios
# Citas
# Ubicacion
# Contacto
# quiero una cita
# 1/1 [==============================] - 0s 26ms/step
# print de return list:  [{'intent': 'horario_cita', 'probability': '1.0'}]
# Tenemos los siguientes horarios disponibles para agendar su cita(escriba el codigo de la cita que desee)
#  H1. Lunes 8:00 a.m
#  H2. Marte 10:00 a.m
#  H3. Miercoles 8:00 a.m
#  H4. Jueves 10:00 a.m
#  H5. Viernes 8:00 a.m
# H5
# 1/1 [==============================] - 0s 30ms/step
# print de return list:  [{'intent': 'agendar_cita', 'probability': '0.9991247'}]
# Perfecto! Ingrese su nombre y numero de celular con el siguiente formato:(nombre xxxx-xxxx)
# Jonatan Santos 6212-8222
# Su cita ha sido correctamente agendada Jonatan
# Lo estaremos llamando al número 6212-8222 para recordarle su cita!
# None
# listo
# 1/1 [==============================] - 0s 31ms/step
# print de return list:  [{'intent': 'sinrespuesta', 'probability': '0.8810606'}]
# no se ha detectado respuesta. Puedes hacerme preguntas como:
# Horario
# Servicios
# Citas
# Ubicacion
# Contacto

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hist.history['accuracy'])
plt.title(' model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(hist.history['loss'])
plt.title(' model accuracy')
plt.ylabel('loss')
plt.xlabel('Epoch')

plt.show()

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               24960
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 33,866
# Trainable params: 33,866
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ![flujograma.png](attachment:flujograma.png)
